# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')
from data import TupleGenerator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### loading
tuple_generator = TupleGenerator()
train, dev, test = tuple_generator.get_vectorized_tuples()
# Out:
# 2019-09-03 14:33:22.105912 Loading comparative data
# 2019-09-03 14:33:22.242650 Loading XKCD data
# 2019-09-03 14:33:23.866903 Vectorizing tuples

# %%
### raw lengths
print("train", len(train))
print("dev", len(dev))
print("----")
print("test")
for k, v in test.items():
    print(k, len(v))
# Out:
# train 14669336
# dev 855597
# ----
# test
# seen_pairings 2319313
# unseen_pairings 211716
# unseen_ref 2147866
# unseen_comp 378345
# fully_unseen 611456

# %%
### original tuples
tuple_generator.train_tuples
# Out:
# [('yellow', ['more', 'off'], 'offyellow'),
#  ('yellow', ['pad', 'dirtier'], 'dirtyyellow'),
#  ('yellow', ['more', 'orange'], 'orangeyellow'),
#  ('yellow', ['pad', 'muddier'], 'muddyyellow'),
#  ('yellow', ['pad', 'brighter'], 'brightyellow'),
#  ('yellow', ['pad', 'sandier'], 'sandyyellow'),
#  ('yellow', ['more', 'burnt'], 'burntyellow'),
#  ('yellow', ['more', 'greenish'], 'greenishyellow'),
#  ('yellow', ['pad', 'darker'], 'darkyellow'),
#  ('yellow', ['pad', 'uglier'], 'uglyyellow'),
#  ('yellow', ['pad', 'browner'], 'brownyellow'),
#  ('yellow', ['more', 'pastel'], 'pastelyellow'),
#  ('yellow', ['pad', 'lighter'], 'lightyellow'),
#  ('yellow', ['more', 'faded'], 'fadedyellow'),
#  ('yellow', ['pad', 'duller'], 'dullyellow'),
#  ('gold', ['pad', 'darker'], 'darkgold'),
#  ('gold', ['pad', 'lighter'], 'lightgold'),
#  ('sand', ['pad', 'darker'], 'darksand'),
#  ('teal', ['more', 'greenish'], 'greenishteal'),
#  ('teal', ['pad', 'deeper'], 'deepteal'),
# ...

# %%
tuple_generator.dev_tuples
# Out:
# [('blue', ['more', 'darkish'], 'darkishblue'),
#  ('blue', ['pad', 'darker'], 'darkblue'),
#  ('blue', ['pad', 'lighter'], 'lightblue'),
#  ('navyblue', ['pad', 'lighter'], 'lightnavyblue'),
#  ('red', ['pad', 'darker'], 'darkred'),
#  ('red', ['pad', 'lighter'], 'lightred')]

# %%
tuple_generator.test_tuples
# Out:
# [('yellow', ['more', 'neon'], 'neonyellow'),
#  ('yellow', ['more', 'off'], 'offyellow'),
#  ('yellow', ['pad', 'dirtier'], 'dirtyyellow'),
#  ('yellow', ['more', 'orange'], 'orangeyellow'),
#  ('yellow', ['pad', 'muddier'], 'muddyyellow'),
#  ('yellow', ['pad', 'brighter'], 'brightyellow'),
#  ('yellow', ['pad', 'sandier'], 'sandyyellow'),
#  ('yellow', ['more', 'burnt'], 'burntyellow'),
#  ('yellow', ['more', 'brownish'], 'brownishyellow'),
#  ('yellow', ['more', 'greenish'], 'greenishyellow'),
#  ('yellow', ['pad', 'darker'], 'darkyellow'),
#  ('yellow', ['pad', 'uglier'], 'uglyyellow'),
#  ('yellow', ['pad', 'browner'], 'brownyellow'),
#  ('yellow', ['pad', 'paler'], 'paleyellow'),
#  ('yellow', ['more', 'pastel'], 'pastelyellow'),
#  ('yellow', ['pad', 'lighter'], 'lightyellow'),
#  ('yellow', ['more', 'faded'], 'fadedyellow'),
#  ('yellow', ['pad', 'duller'], 'dullyellow'),
#  ('gold', ['pad', 'darker'], 'darkgold'),
#  ('gold', ['pad', 'paler'], 'palegold'),
# ...
